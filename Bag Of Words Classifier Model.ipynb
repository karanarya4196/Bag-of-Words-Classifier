# %%
import pandas as pd
df = pd.read_csv('bag_of_words.csv')

# %%
df.columns[-1000:]
# Out:
# Index(['draft revise special', 'preparation of motion', 'inc. re overdue',
#        'correspondence to developers', 'notice of hearing',
#        'preparation of draft', 'cease all work', 'counsel regarding upcoming',
#        'responses to request', 'response to plaintiffs',
#        ...
#        'Line Item Rate', 'Timekeeper Level', 'UTBMS Activity Code',
#        'UTBMS Phase Code', 'UTBMS Task Code', 'Work Area', 'Work Area Level 2',
#        'Is_Prior_Approved', 'Is_Action', 'Class_Label'],
#       dtype='object', length=1000)

# %%
from sklearn.cross_validation import train_test_split
training_set_temp, test_set_temp = train_test_split(df, test_size=0.2, random_state=1)
training_set_temp, dev_set_temp = train_test_split(training_set_temp, test_size=0.2, random_state=1)
# Out:
# C:\Users\Karan.Arya\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
training_set_temp.shape, dev_set_temp.shape, test_set_temp.shape
# Out:
# ((30192, 3556), (7548, 3556), (9436, 3556))

# %%
def fill_feature_using_training(train_set, other_set):
    missing_cols  = set(train_set.columns) - set(other_set.columns)
    new_cols      = set(other_set.columns) - set(train_set.columns)
    
    # Add a missing column in test set with default value equal to 0
    for c in missing_cols:
        other_set[c] = 0
    # Add a missing column in test set with default value equal to 0
    for c in new_cols:
        del other_set[c]
    
    other_set  = other_set[train_set.columns]
    
    return other_set

# %%
training_set_temp['Class_Label'] = np.where(training_set_temp['Class_Label']==True, 1, 0)
training_set_temp = pd.get_dummies(training_set_temp, columns=["Timekeeper Level", "UTBMS Activity Code", "Work Area", "Work Area Level 2", 
                                                              "UTBMS Phase Code", "UTBMS Task Code"])

dev_set_temp      = pd.get_dummies(dev_set_temp, columns=["Timekeeper Level", "UTBMS Activity Code", "Work Area", "Work Area Level 2", 
                                                        "UTBMS Phase Code", "UTBMS Task Code"])
dev_set_temp['Class_Label'] = np.where(dev_set_temp['Class_Label']==True, 1, 0)
dev_set_temp = fill_feature_using_training(training_set_temp, dev_set_temp)


test_set_temp      = pd.get_dummies(test_set_temp, columns=["Timekeeper Level", "UTBMS Activity Code", "Work Area", "Work Area Level 2", 
                                                          "UTBMS Phase Code", "UTBMS Task Code"])
test_set_temp['Class_Label'] = np.where(test_set_temp['Class_Label']==True, 1, 0)
test_set_temp = fill_feature_using_training(training_set_temp, test_set_temp)

print(len(training_set_temp.columns), len(dev_set_temp.columns), len(test_set_temp.columns))

## Only for Bag of words features
for feature in training_set_temp.columns:
    if feature =='Line Item Rate':
        break
    training_set_temp[feature] = training_set_temp[feature].astype(np.uint8)
    dev_set_temp[feature] = dev_set_temp[feature].astype(np.uint8)
    test_set_temp[feature] = test_set_temp[feature].astype(np.uint8)
# Out:
# 3630 3630 3630
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b0d844d3a2e5> in <module>()
#      24     test_set_temp[feature] = test_set_temp[feature].astype(np.uint8)
#      25
# ---> 26 training_set_temp.to_csv('training_' + code[0] + '_final_V1.csv', quoting=1, index=None)
#      27 dev_set_temp.to_csv('dev_' + code[0] + '_final_V1.csv', quoting=1, index=None)
#      28 test_set_temp.to_csv('test_' + code[0] + '_final_V1.csv', quoting=1, index=None)
#
# NameError: name 'code' is not defined

# %%
training_set_temp.to_csv('training_final_V1.csv', quoting=1, index=None)
dev_set_temp.to_csv('dev_final_V1.csv', quoting=1, index=None)
test_set_temp.to_csv('test_final_V1.csv', quoting=1, index=None)

# %% [markdown]
# ### Training classifier

# %%
import numpy as np 
import pandas as pd 
from sklearn.metrics import confusion_matrix 
from sklearn.cross_validation import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import auc, roc_curve

# %%
def train_using_gini(X_train, y_train, max_depth_temp, min_sample_leaf_temp): 
  
    # Creating the classifier object 
    clf_gini = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100, max_depth=max_depth_temp, min_samples_leaf=min_sample_leaf_temp) 
  
    # Performing training 
    clf_gini.fit(X_train, y_train) 
    return clf_gini

# %%
# Function to perform training with entropy. 
def train_using_entropy(X_train, y_train,max_depth_temp, min_sample_leaf_temp): 
  
    # Decision tree with entropy 
    clf_entropy = DecisionTreeClassifier( 
            criterion = "entropy", random_state = 100, 
            max_depth = max_depth_temp, min_samples_leaf = min_sample_leaf_temp) 
  
    # Performing training 
    clf_entropy.fit(X_train, y_train) 
    return clf_entropy

# %%
# Function to make predictions 
def prediction(X_test, clf_object): 
  
    # Predicton on test with giniIndex 
    y_pred = clf_object.predict(X_test) 
    print("Predicted values:") 
    print(y_pred) 
    return y_pred

# %%
# Function to calculate accuracy 
def cal_accuracy(y_test, y_pred): 
      
    print("Confusion Matrix: ", 
        confusion_matrix(y_test, y_pred)) 
      
    print ("Accuracy : ", 
    accuracy_score(y_test, y_pred)*100) 
      
    print("Report : ", 
    classification_report(y_test, y_pred)) 
    
    fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
    print('AUC curve: ', auc(fpr, tpr))

# %%
#dev_set_temp[dev_set_temp['Miles']=='.']

columns = [column for column in training_set_temp.columns if column not in ['Class_Label']]
X_train = training_set_temp[columns].values
y_train = training_set_temp['Class_Label'].values
X_dev   = dev_set_temp[columns].values
y_dev   = dev_set_temp['Class_Label'].values
X_test   = test_set_temp[columns].values
y_test   = test_set_temp['Class_Label'].values

# %%
for depth in [2, 3, 4, 5, 10, 15, 20]:
    print('Depth: ', depth)
    clf_gini = train_using_gini(X_train, y_train, depth, 2) 
    #clf_entropy = train_using_entropy(X_train, y_train, depth) 
    # Operational Phase 
    print("Results Using Gini Index:") 
    # Prediction using gini 
    y_pred_gini = prediction(X_dev, clf_gini)
    #y_pred_gini = prediction(X_dev, clf_entropy)
    cal_accuracy(y_dev, y_pred_gini)
    print('--------------------------------------------------------------------------------')
    print('--------------------------------------------------------------------------------')
# Out:
# Depth:  2
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[7060   11]
#  [ 432   45]]
# Accuracy :  94.13089560148383
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7071
#           1       0.80      0.09      0.17       477
#
# avg / total       0.93      0.94      0.92      7548
#
# AUC curve:  0.5463919864020728
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  3
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[7067    4]
#  [ 433   44]]
# Accuracy :  94.21038685744568
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7071
#           1       0.92      0.09      0.17       477
#
# avg / total       0.94      0.94      0.92      7548
#
# AUC curve:  0.5458387478664294
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  4
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[7065    6]
#  [ 424   53]]
# Accuracy :  94.30312665606783
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7071
#           1       0.90      0.11      0.20       477
#
# avg / total       0.94      0.94      0.92      7548
#
# AUC curve:  0.5551312874180927
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  5
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[7066    5]
#  [ 424   53]]
# Accuracy :  94.31637519872814
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7071
#           1       0.91      0.11      0.20       477
#
# avg / total       0.94      0.94      0.92      7548
#
# AUC curve:  0.5552019987743365
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  10
# Results Using Gini Index:
# Predicted values:
# [0 1 0 ... 0 0 0]
# Confusion Matrix:  [[7030   41]
#  [ 348  129]]
# Accuracy :  94.84631690514044
# Report :               precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      7071
#           1       0.76      0.27      0.40       477
#
# avg / total       0.94      0.95      0.94      7548
#
# AUC curve:  0.6323209601801671
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  15
# Results Using Gini Index:
# Predicted values:
# [0 1 0 ... 0 0 0]
# Confusion Matrix:  [[7009   62]
#  [ 318  159]]
# Accuracy :  94.9655537890832
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      7071
#           1       0.72      0.33      0.46       477
#
# avg / total       0.94      0.95      0.94      7548
#
# AUC curve:  0.6622825625795503
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  20
# Results Using Gini Index:
# Predicted values:
# [0 1 0 ... 0 0 0]
# Confusion Matrix:  [[6992   79]
#  [ 312  165]]
# Accuracy :  94.81981981981981
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      7071
#           1       0.68      0.35      0.46       477
#
# avg / total       0.94      0.95      0.94      7548
#
# AUC curve:  0.667369777699506
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %%
for depth in [2, 3, 4, 5, 10, 15, 20]:
    print('Depth: ', depth)
    clf_gini = train_using_gini(X_train, y_train, depth, 2) 
    #clf_entropy = train_using_entropy(X_train, y_train, depth) 
    # Operational Phase 
    print("Results Using Gini Index:") 
    # Prediction using gini 
    y_pred_gini = prediction(X_test, clf_gini)
    #y_pred_gini = prediction(X_dev, clf_entropy)
    cal_accuracy(y_test, y_pred_gini)
    print('--------------------------------------------------------------------------------')
    print('--------------------------------------------------------------------------------')
# Out:
# Depth:  2
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8790   14]
#  [ 568   64]]
# Accuracy :  93.83213225943197
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      8804
#           1       0.82      0.10      0.18       632
#
# avg / total       0.93      0.94      0.92      9436
#
# AUC curve:  0.5498378182529231
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  3
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8797    7]
#  [ 570   62]]
# Accuracy :  93.8851208139042
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      8804
#           1       0.90      0.10      0.18       632
#
# avg / total       0.94      0.94      0.92      9436
#
# AUC curve:  0.5486530863416514
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  4
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8793   11]
#  [ 545   87]]
# Accuracy :  94.10767274268757
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      8804
#           1       0.89      0.14      0.24       632
#
# avg / total       0.94      0.94      0.92      9436
#
# AUC curve:  0.5682043978858862
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  5
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8797    7]
#  [ 545   87]]
# Accuracy :  94.15006358626536
# Report :               precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      8804
#           1       0.93      0.14      0.24       632
#
# avg / total       0.94      0.94      0.92      9436
#
# AUC curve:  0.5684315673543097
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  10
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8756   48]
#  [ 443  189]]
# Accuracy :  94.79652395082661
# Report :               precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      8804
#           1       0.80      0.30      0.43       632
#
# avg / total       0.94      0.95      0.94      9436
#
# AUC curve:  0.6467992828346149
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  15
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8734   70]
#  [ 398  234]]
# Accuracy :  95.04027130139889
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      8804
#           1       0.77      0.37      0.50       632
#
# avg / total       0.94      0.95      0.94      9436
#
# AUC curve:  0.6811511165810707
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Depth:  20
# Results Using Gini Index:
# Predicted values:
# [0 0 0 ... 0 0 0]
# Confusion Matrix:  [[8711   93]
#  [ 395  237]]
# Accuracy :  94.82831708350996
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      8804
#           1       0.72      0.38      0.49       632
#
# avg / total       0.94      0.95      0.94      9436
#
# AUC curve:  0.6822183098591549
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Training model using XGBoost

# %%
param_test1 = {
 'subsample': [i/10.0 for i in range(6,10)],
 'max_depth':range(3,16,2),
 'min_child_weight':range(1,6,2),

}
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27), 
 param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(train[predictors],train[target])
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_

# %%
subsample = [i/10.0 for i in range(6,10)]
max_depth = list(range(3,16,2))
min_child_weight = list(range(1,6,2))

# %%
for sample in subsample:
    for depth in max_depth:
        for child in min_child_weight:
            print('--------------------------------------------------------------------------------')
            print('--------------------------------------------------------------------------------')
            print('Sample: {}, Depth: {}, Child: {}'.format(sample, depth, child))
            xg_train = create_data_from_df(X_train, y_train)
            xg_dev   = create_data_from_df(X_dev , y_dev)
            param_new = {'subsample': sample, 'max_depth': depth, 'eta': 1, 'min_child_weight': child, 'objective': 'binary:logistic', 
                             'nthread' : 4, 'eval_metric' : ['auc']}
            model    = train_classifier(xg_train, xg_dev, num_round=50, param=param_new)

            xg_test   = create_data_from_df(X_test , y_test)
            print(len(y_test), len(X_test))
            y_pred = predict_test_data(model, xg_test)
            print(len(y_pred))
            y_pred = np.where(y_pred>0.8, 0, 1)
            print(len(y_pred))
            
            cal_accuracy(y_test, y_pred)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.6, Depth: 3, Child: 1
# [17:15:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	eval-auc:0.555781	train-auc:0.55702
# [17:15:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]	eval-auc:0.692218	train-auc:0.689709
# [17:15:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [2]	eval-auc:0.710877	train-auc:0.729205
# [17:15:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [3]	eval-auc:0.735814	train-auc:0.757614
# [17:15:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [4]	eval-auc:0.762124	train-auc:0.77092
# [17:15:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [5]	eval-auc:0.768961	train-auc:0.780935
# [17:15:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [6]	eval-auc:0.785867	train-auc:0.792706
# [17:15:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [7]	eval-auc:0.786093	train-auc:0.79517
# [17:15:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [8]	eval-auc:0.790887	train-auc:0.806612
# [17:15:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [9]	eval-auc:0.789993	train-auc:0.811041
# [17:15:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [10]	eval-auc:0.789342	train-auc:0.814333
# [17:15:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11]	eval-auc:0.790957	train-auc:0.816951
# [17:15:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [12]	eval-auc:0.795348	train-auc:0.822349
# [17:15:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [13]	eval-auc:0.797394	train-auc:0.827922
# [17:15:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14]	eval-auc:0.796848	train-auc:0.831091
# [17:15:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [15]	eval-auc:0.800325	train-auc:0.83103
# [17:15:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [16]	eval-auc:0.806291	train-auc:0.834472
# [17:15:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [17]	eval-auc:0.814049	train-auc:0.841849
# [17:15:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [18]	eval-auc:0.815225	train-auc:0.843537
# [17:15:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19]	eval-auc:0.824225	train-auc:0.848197
# [17:15:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [20]	eval-auc:0.824181	train-auc:0.849928
# [17:15:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [21]	eval-auc:0.825725	train-auc:0.852504
# [17:15:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [22]	eval-auc:0.829014	train-auc:0.856405
# [17:16:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [23]	eval-auc:0.833654	train-auc:0.860387
# [17:16:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [24]	eval-auc:0.833001	train-auc:0.863429
# [17:16:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [25]	eval-auc:0.835902	train-auc:0.864981
# [17:16:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [26]	eval-auc:0.83638	train-auc:0.86792
# [17:16:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [27]	eval-auc:0.840728	train-auc:0.870085
# [17:16:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [28]	eval-auc:0.840566	train-auc:0.871818
# [17:16:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [29]	eval-auc:0.841481	train-auc:0.872116
# [17:16:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [30]	eval-auc:0.843149	train-auc:0.874449
# [17:16:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [31]	eval-auc:0.843331	train-auc:0.875726
# [17:16:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [32]	eval-auc:0.84412	train-auc:0.87755
# [17:16:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [33]	eval-auc:0.844526	train-auc:0.878046
# [17:16:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [34]	eval-auc:0.850325	train-auc:0.88239
# [17:16:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [35]	eval-auc:0.852356	train-auc:0.883126
# [17:16:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [36]	eval-auc:0.85162	train-auc:0.883998
# [17:16:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [37]	eval-auc:0.85205	train-auc:0.884819
# [17:16:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [38]	eval-auc:0.853114	train-auc:0.885348
# [17:16:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [39]	eval-auc:0.854628	train-auc:0.886846
# [17:16:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [40]	eval-auc:0.854189	train-auc:0.888065
# [17:16:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [41]	eval-auc:0.853637	train-auc:0.888694
# [17:16:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [42]	eval-auc:0.852986	train-auc:0.891066
# [17:16:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [43]	eval-auc:0.853863	train-auc:0.892298
# [17:16:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [44]	eval-auc:0.858227	train-auc:0.895064
# [17:16:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [45]	eval-auc:0.858782	train-auc:0.895902
# [17:16:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [46]	eval-auc:0.859594	train-auc:0.897327
# [17:16:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [47]	eval-auc:0.862546	train-auc:0.898859
# [17:16:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [48]	eval-auc:0.864314	train-auc:0.900003
# [17:16:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [49]	eval-auc:0.864307	train-auc:0.900936
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  24 8780]
#  [ 135  497]]
# Accuracy :  5.521407376006782
# Report :               precision    recall  f1-score   support
#
#           0       0.15      0.00      0.01      8804
#           1       0.05      0.79      0.10       632
#
# avg / total       0.14      0.06      0.01      9436
#
# AUC curve:  0.39455921934218624
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.6, Depth: 3, Child: 3
# [17:16:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [0]	eval-auc:0.555758	train-auc:0.557013
# [17:16:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]	eval-auc:0.692052	train-auc:0.689589
# [17:16:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [2]	eval-auc:0.709988	train-auc:0.728666
# [17:16:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [3]	eval-auc:0.735702	train-auc:0.757103
# [17:16:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [4]	eval-auc:0.76113	train-auc:0.770588
# [17:16:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [5]	eval-auc:0.761874	train-auc:0.780233
# [17:17:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [6]	eval-auc:0.767941	train-auc:0.78933
# [17:17:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [7]	eval-auc:0.774539	train-auc:0.793587
# [17:17:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [8]	eval-auc:0.781555	train-auc:0.802296
# [17:17:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [9]	eval-auc:0.789784	train-auc:0.808718
# [17:17:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [10]	eval-auc:0.795286	train-auc:0.818365
# [17:17:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11]	eval-auc:0.798704	train-auc:0.821934
# [17:17:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [12]	eval-auc:0.808882	train-auc:0.827417
# [17:17:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [13]	eval-auc:0.808119	train-auc:0.828469
# [17:17:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [14]	eval-auc:0.807763	train-auc:0.834092
# [17:17:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [15]	eval-auc:0.813413	train-auc:0.83904
# [17:17:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [16]	eval-auc:0.818797	train-auc:0.843024
# [17:17:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [17]	eval-auc:0.819034	train-auc:0.84859
# [17:17:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [18]	eval-auc:0.818381	train-auc:0.848761
# [17:17:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [19]	eval-auc:0.820811	train-auc:0.851025
# [17:17:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [20]	eval-auc:0.821588	train-auc:0.853229
# [17:17:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [21]	eval-auc:0.826589	train-auc:0.856499
# [17:17:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [22]	eval-auc:0.829795	train-auc:0.858232
# [17:17:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23]	eval-auc:0.833179	train-auc:0.8611
# [17:17:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [24]	eval-auc:0.833607	train-auc:0.862077
# [17:17:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [25]	eval-auc:0.834881	train-auc:0.863375
# [17:17:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [26]	eval-auc:0.837413	train-auc:0.866936
# [17:17:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [27]	eval-auc:0.837471	train-auc:0.869118
# [17:17:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [28]	eval-auc:0.839641	train-auc:0.870119
# [17:17:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [29]	eval-auc:0.842047	train-auc:0.87184
# [17:17:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]	eval-auc:0.842241	train-auc:0.875025
# [17:17:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [31]	eval-auc:0.842559	train-auc:0.875585
# [17:17:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [32]	eval-auc:0.845279	train-auc:0.877448
# [17:17:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [33]	eval-auc:0.84841	train-auc:0.879232
# [17:17:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [34]	eval-auc:0.848121	train-auc:0.880235
# [17:17:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [35]	eval-auc:0.8481	train-auc:0.880913
# [17:17:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [36]	eval-auc:0.850003	train-auc:0.88238
# [17:17:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [37]	eval-auc:0.850671	train-auc:0.883282
# [17:17:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [38]	eval-auc:0.848927	train-auc:0.883357
# [17:17:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [39]	eval-auc:0.851441	train-auc:0.884905
# [17:17:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [40]	eval-auc:0.852346	train-auc:0.886726
# [17:17:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [41]	eval-auc:0.851222	train-auc:0.886637
# [17:17:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [42]	eval-auc:0.848869	train-auc:0.887348
# [17:17:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [43]	eval-auc:0.851563	train-auc:0.888211
# [17:17:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [44]	eval-auc:0.84975	train-auc:0.888335
# [17:17:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [45]	eval-auc:0.849745	train-auc:0.888714
# [17:18:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [46]	eval-auc:0.850124	train-auc:0.889435
# [17:18:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [47]	eval-auc:0.84916	train-auc:0.889
# [17:18:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [48]	eval-auc:0.84963	train-auc:0.889179
# [17:18:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [49]	eval-auc:0.846713	train-auc:0.88989
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  18 8786]
#  [ 119  513]]
# Accuracy :  5.627384484951251
# Report :               precision    recall  f1-score   support
#
#           0       0.13      0.00      0.00      8804
#           1       0.06      0.81      0.10       632
#
# avg / total       0.13      0.06      0.01      9436
#
# AUC curve:  0.40687669298765233
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.6, Depth: 3, Child: 5
# [17:18:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [0]	eval-auc:0.555739	train-auc:0.556981
# [17:18:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]	eval-auc:0.69202	train-auc:0.689563
# [17:18:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [2]	eval-auc:0.7004	train-auc:0.716037
# [17:18:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [3]	eval-auc:0.734495	train-auc:0.755148
# [17:18:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [4]	eval-auc:0.745525	train-auc:0.762095
# [17:18:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [5]	eval-auc:0.761482	train-auc:0.777584
# [17:18:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [6]	eval-auc:0.762462	train-auc:0.779761
# [17:18:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [7]	eval-auc:0.773484	train-auc:0.789867
# [17:18:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [8]	eval-auc:0.77784	train-auc:0.794475
# [17:18:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [9]	eval-auc:0.781692	train-auc:0.801418
# [17:18:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10]	eval-auc:0.785117	train-auc:0.808292
# [17:18:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11]	eval-auc:0.789466	train-auc:0.814558
# [17:18:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [12]	eval-auc:0.790959	train-auc:0.816787
# [17:18:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [13]	eval-auc:0.795535	train-auc:0.820854
# [17:18:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14]	eval-auc:0.793781	train-auc:0.824879
# [17:18:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [15]	eval-auc:0.795185	train-auc:0.827248
# [17:18:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [16]	eval-auc:0.800063	train-auc:0.830829
# [17:18:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [17]	eval-auc:0.804909	train-auc:0.836957
# [17:18:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [18]	eval-auc:0.807153	train-auc:0.84218
# [17:18:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19]	eval-auc:0.813881	train-auc:0.84709
# [17:18:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [20]	eval-auc:0.816453	train-auc:0.847066
# [17:18:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [21]	eval-auc:0.822914	train-auc:0.851703
# [17:18:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [22]	eval-auc:0.82562	train-auc:0.853311
# [17:18:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [23]	eval-auc:0.826728	train-auc:0.854444
# [17:18:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [24]	eval-auc:0.824598	train-auc:0.856345
# [17:18:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [25]	eval-auc:0.827075	train-auc:0.85764
# [17:18:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [26]	eval-auc:0.832925	train-auc:0.861907
# [17:18:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [27]	eval-auc:0.834751	train-auc:0.862735
# [17:18:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [28]	eval-auc:0.835822	train-auc:0.864269
# [17:19:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [29]	eval-auc:0.836422	train-auc:0.868043
# [17:19:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]	eval-auc:0.839081	train-auc:0.871247
# [17:19:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [31]	eval-auc:0.840772	train-auc:0.872686
# [17:19:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [32]	eval-auc:0.840471	train-auc:0.873458
# [17:19:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [33]	eval-auc:0.844426	train-auc:0.876558
# [17:19:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [34]	eval-auc:0.846485	train-auc:0.877316
# [17:19:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [35]	eval-auc:0.846942	train-auc:0.878651
# [17:19:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [36]	eval-auc:0.846756	train-auc:0.881428
# [17:19:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [37]	eval-auc:0.848709	train-auc:0.883702
# [17:19:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [38]	eval-auc:0.846543	train-auc:0.883756
# [17:19:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [39]	eval-auc:0.846758	train-auc:0.885391
# [17:19:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [40]	eval-auc:0.84845	train-auc:0.887264
# [17:19:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [41]	eval-auc:0.847881	train-auc:0.887849
# [17:19:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [42]	eval-auc:0.848591	train-auc:0.888087
# [17:19:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [43]	eval-auc:0.84944	train-auc:0.888692
# [17:19:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [44]	eval-auc:0.851265	train-auc:0.889441
# [17:19:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [45]	eval-auc:0.853216	train-auc:0.891571
# [17:19:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [46]	eval-auc:0.855452	train-auc:0.894409
# [17:19:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [47]	eval-auc:0.852828	train-auc:0.895276
# [17:19:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [48]	eval-auc:0.85428	train-auc:0.896127
# [17:19:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [49]	eval-auc:0.854092	train-auc:0.897055
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  18 8786]
#  [ 119  513]]
# Accuracy :  5.627384484951251
# Report :               precision    recall  f1-score   support
#
#           0       0.13      0.00      0.00      8804
#           1       0.06      0.81      0.10       632
#
# avg / total       0.13      0.06      0.01      9436
#
# AUC curve:  0.40687669298765233
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.6, Depth: 5, Child: 1
# [17:19:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [0]	eval-auc:0.616673	train-auc:0.619534
# [17:19:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [1]	eval-auc:0.725223	train-auc:0.743846
# [17:19:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [2]	eval-auc:0.754494	train-auc:0.780431
# [17:19:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [3]	eval-auc:0.782643	train-auc:0.815342
# [17:19:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [4]	eval-auc:0.798276	train-auc:0.822833
# [17:19:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [5]	eval-auc:0.807795	train-auc:0.835965
# [17:19:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [6]	eval-auc:0.812943	train-auc:0.844373
# [17:19:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [7]	eval-auc:0.820557	train-auc:0.849227
# [17:19:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [8]	eval-auc:0.823359	train-auc:0.854985
# [17:20:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [9]	eval-auc:0.823136	train-auc:0.860109
# [17:20:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10]	eval-auc:0.83357	train-auc:0.865976
# [17:20:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [11]	eval-auc:0.837039	train-auc:0.870653
# [17:20:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [12]	eval-auc:0.842538	train-auc:0.875703
# [17:20:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [13]	eval-auc:0.84794	train-auc:0.878586
# [17:20:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [14]	eval-auc:0.850439	train-auc:0.881969
# [17:20:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [15]	eval-auc:0.853085	train-auc:0.885694
# [17:20:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [16]	eval-auc:0.854679	train-auc:0.888952
# [17:20:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [17]	eval-auc:0.855725	train-auc:0.893036
# [17:20:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [18]	eval-auc:0.854831	train-auc:0.894852
# [17:20:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [19]	eval-auc:0.857408	train-auc:0.897668
# [17:20:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [20]	eval-auc:0.859096	train-auc:0.89963
# [17:20:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [21]	eval-auc:0.856385	train-auc:0.900553
# [17:20:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [22]	eval-auc:0.85968	train-auc:0.904017
# [17:20:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [23]	eval-auc:0.863468	train-auc:0.908127
# [17:20:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [24]	eval-auc:0.862441	train-auc:0.909131
# [17:20:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [25]	eval-auc:0.863441	train-auc:0.911032
# [17:20:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [26]	eval-auc:0.865942	train-auc:0.915115
# [17:20:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [27]	eval-auc:0.864259	train-auc:0.916003
# [17:20:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [28]	eval-auc:0.86678	train-auc:0.918436
# [17:20:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [29]	eval-auc:0.869064	train-auc:0.921652
# [17:20:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [30]	eval-auc:0.870039	train-auc:0.922748
# [17:20:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [31]	eval-auc:0.86997	train-auc:0.924305
# [17:20:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [32]	eval-auc:0.86925	train-auc:0.925946
# [17:20:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [33]	eval-auc:0.870405	train-auc:0.928402
# [17:20:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [34]	eval-auc:0.870018	train-auc:0.929989
# [17:20:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [35]	eval-auc:0.87388	train-auc:0.931403
# [17:20:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [36]	eval-auc:0.874618	train-auc:0.934007
# [17:21:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [37]	eval-auc:0.874759	train-auc:0.935376
# [17:21:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [38]	eval-auc:0.878475	train-auc:0.936318
# [17:21:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [39]	eval-auc:0.876576	train-auc:0.937671
# [17:21:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [40]	eval-auc:0.87909	train-auc:0.93916
# [17:21:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [41]	eval-auc:0.87847	train-auc:0.939409
# [17:21:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [42]	eval-auc:0.877664	train-auc:0.939375
# [17:21:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [43]	eval-auc:0.878508	train-auc:0.940505
# [17:21:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [44]	eval-auc:0.879554	train-auc:0.941039
# [17:21:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [45]	eval-auc:0.880765	train-auc:0.941716
# [17:21:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [46]	eval-auc:0.881324	train-auc:0.942282
# [17:21:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [47]	eval-auc:0.882346	train-auc:0.943148
# [17:21:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [48]	eval-auc:0.883468	train-auc:0.944333
# [17:21:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [49]	eval-auc:0.883408	train-auc:0.944464
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  23 8781]
#  [ 182  450]]
# Accuracy :  5.012717253073337
# Report :               precision    recall  f1-score   support
#
#           0       0.11      0.00      0.01      8804
#           1       0.05      0.71      0.09       632
#
# avg / total       0.11      0.05      0.01      9436
#
# AUC curve:  0.3573188826712829
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.6, Depth: 5, Child: 3
# [17:21:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [0]	eval-auc:0.616669	train-auc:0.619519
# [17:21:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [1]	eval-auc:0.721119	train-auc:0.736291
# [17:21:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [2]	eval-auc:0.739015	train-auc:0.779789
# [17:21:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [3]	eval-auc:0.780327	train-auc:0.822231
# [17:21:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [4]	eval-auc:0.813751	train-auc:0.838778
# [17:21:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [5]	eval-auc:0.815763	train-auc:0.844601
# [17:21:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [6]	eval-auc:0.813757	train-auc:0.84899
# [17:21:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [7]	eval-auc:0.817441	train-auc:0.854552
# [17:21:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [8]	eval-auc:0.815259	train-auc:0.858969
# [17:21:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [9]	eval-auc:0.818666	train-auc:0.865748
# [17:22:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10]	eval-auc:0.818327	train-auc:0.869146
# [17:22:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [11]	eval-auc:0.819953	train-auc:0.871559
# [17:22:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [12]	eval-auc:0.823261	train-auc:0.875099
# [17:22:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [13]	eval-auc:0.827063	train-auc:0.879255
# [17:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14]	eval-auc:0.83098	train-auc:0.881992
# [17:22:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [15]	eval-auc:0.836626	train-auc:0.887792
# [17:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [16]	eval-auc:0.83915	train-auc:0.890442
# [17:22:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [17]	eval-auc:0.840725	train-auc:0.891819
# [17:22:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [18]	eval-auc:0.843212	train-auc:0.893489
# [17:22:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [19]	eval-auc:0.848335	train-auc:0.896829
# [17:22:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [20]	eval-auc:0.85066	train-auc:0.896843
# [17:22:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [21]	eval-auc:0.850063	train-auc:0.897721
# [17:22:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [22]	eval-auc:0.854189	train-auc:0.899836
# [17:22:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [23]	eval-auc:0.857159	train-auc:0.902475
# [17:22:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [24]	eval-auc:0.858052	train-auc:0.904068
# [17:22:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [25]	eval-auc:0.8573	train-auc:0.905709
# [17:22:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [26]	eval-auc:0.857873	train-auc:0.906177
# [17:22:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [27]	eval-auc:0.857172	train-auc:0.907796
# [17:22:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [28]	eval-auc:0.857468	train-auc:0.908871
# [17:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [29]	eval-auc:0.855866	train-auc:0.910289
# [17:22:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [30]	eval-auc:0.856844	train-auc:0.91137
# [17:22:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [31]	eval-auc:0.855548	train-auc:0.912326
# [17:22:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [32]	eval-auc:0.858533	train-auc:0.915044
# [17:22:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [33]	eval-auc:0.858134	train-auc:0.917402
# [17:22:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [34]	eval-auc:0.857855	train-auc:0.91801
# [17:22:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [35]	eval-auc:0.857921	train-auc:0.919518
# [17:22:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [36]	eval-auc:0.859615	train-auc:0.920888
# ...
# [22]	eval-auc:0.900425	train-auc:0.977858
# [21:35:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=15
# [23]	eval-auc:0.901153	train-auc:0.978712
# [21:35:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=15
# [24]	eval-auc:0.90225	train-auc:0.979459
# [21:35:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=15
# [25]	eval-auc:0.901007	train-auc:0.980744
# [21:35:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=15
# [26]	eval-auc:0.902796	train-auc:0.981017
# [21:35:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=15
# [27]	eval-auc:0.903702	train-auc:0.981511
# [21:35:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=15
# [28]	eval-auc:0.903437	train-auc:0.982103
# [21:35:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=15
# [29]	eval-auc:0.903473	train-auc:0.982653
# [21:35:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=15
# [30]	eval-auc:0.90306	train-auc:0.983029
# [21:35:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=15
# [31]	eval-auc:0.903515	train-auc:0.983335
# [21:35:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=15
# [32]	eval-auc:0.903552	train-auc:0.983637
# [21:35:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=15
# [33]	eval-auc:0.903604	train-auc:0.984173
# [21:35:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [34]	eval-auc:0.904197	train-auc:0.984573
# [21:36:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=15
# [35]	eval-auc:0.905524	train-auc:0.985172
# [21:36:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=15
# [36]	eval-auc:0.906119	train-auc:0.985575
# [21:36:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=15
# [37]	eval-auc:0.905687	train-auc:0.98614
# [21:36:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=15
# [38]	eval-auc:0.905954	train-auc:0.986549
# [21:36:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=15
# [39]	eval-auc:0.906237	train-auc:0.986795
# [21:36:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=15
# [40]	eval-auc:0.906492	train-auc:0.986975
# [21:36:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=15
# [41]	eval-auc:0.907023	train-auc:0.987306
# [21:36:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=15
# [42]	eval-auc:0.906141	train-auc:0.987824
# [21:36:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [43]	eval-auc:0.906844	train-auc:0.988295
# [21:36:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=15
# [44]	eval-auc:0.906937	train-auc:0.988741
# [21:36:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=15
# [45]	eval-auc:0.907607	train-auc:0.989385
# [21:36:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=15
# [46]	eval-auc:0.907354	train-auc:0.989834
# [21:37:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=15
# [47]	eval-auc:0.907561	train-auc:0.989865
# [21:37:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [48]	eval-auc:0.908048	train-auc:0.989957
# [21:37:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=15
# [49]	eval-auc:0.909126	train-auc:0.990511
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  43 8761]
#  [ 230  402]]
# Accuracy :  4.7159813480288255
# Report :               precision    recall  f1-score   support
#
#           0       0.16      0.00      0.01      8804
#           1       0.04      0.64      0.08       632
#
# avg / total       0.15      0.05      0.01      9436
#
# AUC curve:  0.3204800464690963
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sample: 0.9, Depth: 15, Child: 5
# [21:37:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=15
# [0]	eval-auc:0.766359	train-auc:0.802867
# [21:37:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=15
# [1]	eval-auc:0.84208	train-auc:0.870196
# [21:37:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=15
# [2]	eval-auc:0.847132	train-auc:0.885361
# [21:37:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [3]	eval-auc:0.856347	train-auc:0.901421
# [21:37:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [4]	eval-auc:0.865239	train-auc:0.915164
# [21:37:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=15
# [5]	eval-auc:0.871652	train-auc:0.922619
# [21:37:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=15
# [6]	eval-auc:0.872865	train-auc:0.929021
# [21:38:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=15
# [7]	eval-auc:0.871039	train-auc:0.931791
# [21:38:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=15
# [8]	eval-auc:0.873199	train-auc:0.935889
# [21:38:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=15
# [9]	eval-auc:0.877688	train-auc:0.940424
# [21:38:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=15
# [10]	eval-auc:0.877009	train-auc:0.94429
# [21:38:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=15
# [11]	eval-auc:0.877826	train-auc:0.947098
# [21:38:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=15
# [12]	eval-auc:0.880566	train-auc:0.949527
# [21:38:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=15
# [13]	eval-auc:0.882704	train-auc:0.952106
# [21:38:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=15
# [14]	eval-auc:0.884759	train-auc:0.95367
# [21:38:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=15
# [15]	eval-auc:0.884694	train-auc:0.956179
# [21:38:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=15
# [16]	eval-auc:0.885914	train-auc:0.958396
# [21:38:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=15
# [17]	eval-auc:0.889895	train-auc:0.96023
# [21:38:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=15
# [18]	eval-auc:0.88914	train-auc:0.962105
# [21:39:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=15
# [19]	eval-auc:0.887842	train-auc:0.964181
# [21:39:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=15
# [20]	eval-auc:0.888445	train-auc:0.965726
# [21:39:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=15
# [21]	eval-auc:0.886966	train-auc:0.966528
# [21:39:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=15
# [22]	eval-auc:0.887842	train-auc:0.966769
# [21:39:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=15
# [23]	eval-auc:0.889465	train-auc:0.967214
# [21:39:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=15
# [24]	eval-auc:0.889563	train-auc:0.968176
# [21:39:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=15
# [25]	eval-auc:0.89042	train-auc:0.968811
# [21:39:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=15
# [26]	eval-auc:0.890062	train-auc:0.969403
# [21:39:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=15
# [27]	eval-auc:0.890603	train-auc:0.970014
# [21:39:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=15
# [28]	eval-auc:0.89252	train-auc:0.971215
# [21:39:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=15
# [29]	eval-auc:0.892434	train-auc:0.972427
# [21:39:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=15
# [30]	eval-auc:0.892492	train-auc:0.97315
# [21:40:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=15
# [31]	eval-auc:0.892653	train-auc:0.973957
# [21:40:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=15
# [32]	eval-auc:0.892139	train-auc:0.97446
# [21:40:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=15
# [33]	eval-auc:0.891416	train-auc:0.975574
# [21:40:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=15
# [34]	eval-auc:0.891131	train-auc:0.976041
# [21:40:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=15
# [35]	eval-auc:0.894198	train-auc:0.976932
# [21:40:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=15
# [36]	eval-auc:0.892622	train-auc:0.977494
# [21:40:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=15
# [37]	eval-auc:0.894573	train-auc:0.978551
# [21:40:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=15
# [38]	eval-auc:0.896151	train-auc:0.978822
# [21:40:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=15
# [39]	eval-auc:0.897572	train-auc:0.979567
# [21:40:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=15
# [40]	eval-auc:0.898012	train-auc:0.980089
# [21:40:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=15
# [41]	eval-auc:0.898414	train-auc:0.98174
# [21:40:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=15
# [42]	eval-auc:0.899333	train-auc:0.982437
# [21:41:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=15
# [43]	eval-auc:0.900185	train-auc:0.982652
# [21:41:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=15
# [44]	eval-auc:0.900094	train-auc:0.982991
# [21:41:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=15
# [45]	eval-auc:0.89979	train-auc:0.983517
# [21:41:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=15
# [46]	eval-auc:0.900694	train-auc:0.983593
# [21:41:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=15
# [47]	eval-auc:0.900878	train-auc:0.984273
# [21:41:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=15
# [48]	eval-auc:0.901856	train-auc:0.984808
# [21:41:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=15
# [49]	eval-auc:0.900574	train-auc:0.985511
# 9436 9436
# 9436
# 9436
# Confusion Matrix:  [[  37 8767]
#  [ 221  411]]
# Accuracy :  4.747774480712167
# Report :               precision    recall  f1-score   support
#
#           0       0.14      0.00      0.01      8804
#           1       0.04      0.65      0.08       632
#
# avg / total       0.14      0.05      0.01      9436
#
# AUC curve:  0.32725954543101815

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state = 1)
rf.fit(X_train, y_train)

predictions_dev = rf.predict(X_dev)
predictions_test = rf.predict(X_test)

cal_accuracy(y_dev, predictions_dev)
cal_accuracy(y_test, predictions_test)
# Out:
# Confusion Matrix:  [[7013   58]
#  [ 277  200]]
# Accuracy :  95.56173820879704
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      7071
#           1       0.78      0.42      0.54       477
#
# avg / total       0.95      0.96      0.95      7548
#
# AUC curve:  0.7055423472078799
# Confusion Matrix:  [[8731   73]
#  [ 358  274]]
# Accuracy :  95.43238660449343
# Report :               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      8804
#           1       0.79      0.43      0.56       632
#
# avg / total       0.95      0.95      0.95      9436
#
# AUC curve:  0.7126263091000063
